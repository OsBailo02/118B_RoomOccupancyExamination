# %% [markdown]
#  # Importing Significant Packages

# %%
import pandas as pd
import pickle 
import matplotlib.pyplot as plt
import statsmodels
import numpy as np
import seaborn as sns
from numpy import array
from scipy.stats import norm
from statsmodels.formula.api import logit
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn import preprocessing

# %% [markdown]
# # Data Exploration

# %%
# Reading in Data
data = pd.read_csv("occupancy.csv", parse_dates= ["date"])

# %%
def process_dates(df):
    df["year"] = df.date.dt.year
    df["month"] = df.date.dt.month
    df["day"] = df.date.dt.day
    df["hour"] = df.date.dt.hour
    df["minute"] = df.date.dt.minute
    df["day_of_week"] = df.date.dt.dayofweek

# %%
process_dates(data)

# %%
# Visualizing Structure
data.head()
# Out:
#                  date  Temperature  Humidity       Light         CO2  \
# 0 2015-02-02 14:19:00      23.7000    26.272  585.200000  749.200000
# 1 2015-02-02 14:19:00      23.7180    26.290  578.400000  760.400000
# 2 2015-02-02 14:21:00      23.7300    26.230  572.666667  769.666667
# 3 2015-02-02 14:22:00      23.7225    26.125  493.750000  774.750000
# 4 2015-02-02 14:23:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy  year  month  day  hour  minute  day_of_week
# 0       0.004764          1  2015      2    2    14      19            0
# 1       0.004773          1  2015      2    2    14      19            0
# 2       0.004765          1  2015      2    2    14      21            0
# 3       0.004744          1  2015      2    2    14      22            0
# 4       0.004767          1  2015      2    2    14      23            0

# %%
# Looking for the first occurence of a weekend begins on the 5914ith observation
data.iloc[5913:]
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 5913  2015-06-02 23:58:00      20.0000   18.7000    0.0  440.000000
# 5914  2015-07-02 00:00:00      20.0000   18.7000    0.0  438.000000
# 5915  2015-07-02 00:01:00      19.9725   18.7450    0.0  433.666667
# 5916  2015-07-02 00:02:00      20.0000   18.7900    0.0  434.500000
# 5917  2015-07-02 00:03:00      20.0000   18.7000    0.0  434.000000
# ...                   ...          ...       ...    ...         ...
# 10803 2015-10-02 09:29:00      21.0500   36.0975  433.0  787.250000
# 10804 2015-10-02 09:29:00      21.0500   35.9950  433.0  789.500000
# 10805 2015-10-02 09:30:00      21.1000   36.0950  433.0  798.500000
# 10806 2015-10-02 09:32:00      21.1000   36.2600  433.0  820.333333
# 10807 2015-10-02 09:33:00      21.1000   36.2000  447.0  821.000000
#
#        HumidityRatio  Occupancy  year  month  day  hour  minute  day_of_week
# 5913        0.002696          0  2015      6    2    23      58            1
# 5914        0.002696          0  2015      7    2     0       0            3
# 5915        0.002698          0  2015      7    2     0       1            3
# 5916        0.002709          0  2015      7    2     0       2            3
# 5917        0.002696          0  2015      7    2     0       3            3
# ...              ...        ...   ...    ...  ...   ...     ...          ...
# 10803       0.005579          1  2015     10    2     9      29            4
# 10804       0.005563          1  2015     10    2     9      29            4
# 10805       0.005596          1  2015     10    2     9      30            4
# 10806       0.005621          1  2015     10    2     9      32            4
# 10807       0.005612          1  2015     10    2     9      33            4
#
# [4895 rows x 13 columns]

# %%
# The weekend ends on the 8794th observation with the rest being weekdays
data.iloc[8792:]
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 8792  2015-08-02 23:57:00        19.50   27.1000    0.0  459.000000
# 8793  2015-08-02 23:58:00        19.50   27.1000    0.0  458.000000
# 8794  2015-09-02 00:00:00        19.50   27.1000    0.0  459.000000
# 8795  2015-09-02 00:01:00        19.50   27.1000    0.0  459.000000
# 8796  2015-09-02 00:02:00        19.50   27.1000    0.0  458.000000
# ...                   ...          ...       ...    ...         ...
# 10803 2015-10-02 09:29:00        21.05   36.0975  433.0  787.250000
# 10804 2015-10-02 09:29:00        21.05   35.9950  433.0  789.500000
# 10805 2015-10-02 09:30:00        21.10   36.0950  433.0  798.500000
# 10806 2015-10-02 09:32:00        21.10   36.2600  433.0  820.333333
# 10807 2015-10-02 09:33:00        21.10   36.2000  447.0  821.000000
#
#        HumidityRatio  Occupancy  year  month  day  hour  minute  day_of_week
# 8792        0.003795          0  2015      8    2    23      57            6
# 8793        0.003795          0  2015      8    2    23      58            6
# 8794        0.003795          0  2015      9    2     0       0            2
# 8795        0.003795          0  2015      9    2     0       1            2
# 8796        0.003795          0  2015      9    2     0       2            2
# ...              ...        ...   ...    ...  ...   ...     ...          ...
# 10803       0.005579          1  2015     10    2     9      29            4
# 10804       0.005563          1  2015     10    2     9      29            4
# 10805       0.005596          1  2015     10    2     9      30            4
# 10806       0.005621          1  2015     10    2     9      32            4
# 10807       0.005612          1  2015     10    2     9      33            4
#
# [2016 rows x 13 columns]

# %%
# Setting a new binary column parameter known as weekday
data["weekday"] = data.day_of_week.map(lambda x: 1 if x not in [5, 6] else 0)
data.head()
# Out:
#                  date  Temperature  Humidity       Light         CO2  \
# 0 2015-02-02 14:19:00      23.7000    26.272  585.200000  749.200000
# 1 2015-02-02 14:19:00      23.7180    26.290  578.400000  760.400000
# 2 2015-02-02 14:21:00      23.7300    26.230  572.666667  769.666667
# 3 2015-02-02 14:22:00      23.7225    26.125  493.750000  774.750000
# 4 2015-02-02 14:23:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy  year  month  day  hour  minute  day_of_week  \
# 0       0.004764          1  2015      2    2    14      19            0
# 1       0.004773          1  2015      2    2    14      19            0
# 2       0.004765          1  2015      2    2    14      21            0
# 3       0.004744          1  2015      2    2    14      22            0
# 4       0.004767          1  2015      2    2    14      23            0
#
#    weekday
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# Here we are now left with a relatively cleaner dataframe in terms of date along with an added Day parameter from EDA.

# %%
data.to_csv("cleaned_occupancy.csv", index=False)

# %% [markdown]
# # Checking for Disruptive Noise/Bias

# %%
print(data.any())
# Out:
# date             True
# Temperature      True
# Humidity         True
# Light            True
# CO2              True
# HumidityRatio    True
# Occupancy        True
# year             True
# month            True
# day              True
# hour             True
# minute           True
# day_of_week      True
# weekday          True
# dtype: bool

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10808 entries, 0 to 10807
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           10808 non-null  datetime64[ns]
#  1   Temperature    10808 non-null  float64
#  2   Humidity       10808 non-null  float64
#  3   Light          10808 non-null  float64
#  4   CO2            10808 non-null  float64
#  5   HumidityRatio  10808 non-null  float64
#  6   Occupancy      10808 non-null  int64
#  7   year           10808 non-null  int64
#  8   month          10808 non-null  int64
#  9   day            10808 non-null  int64
#  10  hour           10808 non-null  int64
#  11  minute         10808 non-null  int64
#  12  day_of_week    10808 non-null  int64
#  13  weekday        10808 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(8)
# memory usage: 1.2 MB
# None

# %%
#print(data['Temperature'].unique())

# %%
#print(data['Humidity'].unique())

# %%
#print( data['Light'].unique())

# %% [markdown]
# # Removing any rows with NaN values
# ## Ensures a better estimation by eliminating nonexistent values

# %%
data.shape
# Out:
# (10808, 14)

# %%
df = data.dropna()

# %%
data.shape
# Out:
# (10808, 14)

# %% [markdown]
# ## As noticed, 8 rows were removed due to any missing value in any column
# ### running print(data.info()), we can notice that the column day of time had 10800 non-null values, hence being the remmoved NaN values
# ### look at rows

# %%
df = df.drop(columns = ['date'])

# %%
plt.matshow(df.corr())
plt.show()

# %%
df.corr()
# Out:
#                Temperature  Humidity     Light       CO2  HumidityRatio  \
# Temperature       1.000000 -0.040270  0.685543  0.640987       0.303167
# Humidity         -0.040270  1.000000  0.104641  0.469475       0.938169
# Light             0.685543  0.104641  1.000000  0.693588       0.335745
# CO2               0.640987  0.469475  0.693588  1.000000       0.686438
# HumidityRatio     0.303167  0.938169  0.335745  0.686438       1.000000
# Occupancy         0.595005  0.183020  0.915363  0.729540       0.386346
# year                   NaN       NaN       NaN       NaN            NaN
# month            -0.511861  0.408285 -0.182425 -0.080087       0.204604
# day                    NaN       NaN       NaN       NaN            NaN
# hour              0.273039  0.056862  0.085024  0.237897       0.148143
# minute           -0.003472 -0.003690  0.024457 -0.002940      -0.004766
# day_of_week      -0.349749  0.224989 -0.211269 -0.278649       0.077761
# weekday           0.184528 -0.128539  0.076912  0.142666      -0.047157
#
#                Occupancy  year     month  day      hour    minute  \
# Temperature     0.595005   NaN -0.511861  NaN  0.273039 -0.003472
# Humidity        0.183020   NaN  0.408285  NaN  0.056862 -0.003690
# Light           0.915363   NaN -0.182425  NaN  0.085024  0.024457
# CO2             0.729540   NaN -0.080087  NaN  0.237897 -0.002940
# HumidityRatio   0.386346   NaN  0.204604  NaN  0.148143 -0.004766
# Occupancy       1.000000   NaN -0.177545  NaN  0.085563  0.012545
# year                 NaN   NaN       NaN  NaN       NaN       NaN
# month          -0.177545   NaN  1.000000  NaN -0.176194 -0.006915
# day                  NaN   NaN       NaN  NaN       NaN       NaN
# hour            0.085563   NaN -0.176194  NaN  1.000000  0.004185
# minute          0.012545   NaN -0.006915  NaN  0.004185  1.000000
# day_of_week    -0.246418   NaN  0.476177  NaN -0.108361 -0.004331
# weekday         0.087360   NaN -0.111140  NaN -0.007508 -0.000771
#
#                day_of_week   weekday
# Temperature      -0.349749  0.184528
# Humidity          0.224989 -0.128539
# Light            -0.211269  0.076912
# CO2              -0.278649  0.142666
# HumidityRatio     0.077761 -0.047157
# Occupancy        -0.246418  0.087360
# year                   NaN       NaN
# month             0.476177 -0.111140
# day                    NaN       NaN
# hour             -0.108361 -0.007508
# minute           -0.004331 -0.000771
# day_of_week       1.000000 -0.818408
# weekday          -0.818408  1.000000

# %%
# Let us drop weekday as day_of_week gives us enough info here
df = df.drop(columns = ["weekday"])

# %%
df
# Out:
#        Temperature  Humidity       Light         CO2  HumidityRatio  \
# 0          23.7000   26.2720  585.200000  749.200000       0.004764
# 1          23.7180   26.2900  578.400000  760.400000       0.004773
# 2          23.7300   26.2300  572.666667  769.666667       0.004765
# 3          23.7225   26.1250  493.750000  774.750000       0.004744
# 4          23.7540   26.2000  488.600000  779.000000       0.004767
# ...            ...       ...         ...         ...            ...
# 10803      21.0500   36.0975  433.000000  787.250000       0.005579
# 10804      21.0500   35.9950  433.000000  789.500000       0.005563
# 10805      21.1000   36.0950  433.000000  798.500000       0.005596
# 10806      21.1000   36.2600  433.000000  820.333333       0.005621
# 10807      21.1000   36.2000  447.000000  821.000000       0.005612
#
#        Occupancy  year  month  day  hour  minute  day_of_week
# 0              1  2015      2    2    14      19            0
# 1              1  2015      2    2    14      19            0
# 2              1  2015      2    2    14      21            0
# 3              1  2015      2    2    14      22            0
# 4              1  2015      2    2    14      23            0
# ...          ...   ...    ...  ...   ...     ...          ...
# 10803          1  2015     10    2     9      29            4
# 10804          1  2015     10    2     9      29            4
# 10805          1  2015     10    2     9      30            4
# 10806          1  2015     10    2     9      32            4
# 10807          1  2015     10    2     9      33            4
#
# [10808 rows x 12 columns]

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# We choose not to do PCA here, even though we have correlations as we want to preserve our features to compute
# feature importances

# %%
clf = Pipeline([
  ('feature_selection', SelectFromModel(ExtraTreesClassifier())),
  ('classification', RandomForestClassifier())
])

# %%
X = df.drop(columns = ['Occupancy'])
y = df.Occupancy

# %%
clf = ExtraTreesClassifier()
clf = clf.fit(X, y)
clf.feature_importances_
# Out:
# array([0.10367591, 0.03490272, 0.3885138 , 0.25231492, 0.05699547,
#        0.        , 0.02866157, 0.        , 0.09170278, 0.01218799,
#        0.03104484])

# %%
model = SelectFromModel(clf, prefit=True)

# %%
for ind, item in enumerate(np.argsort(clf.feature_importances_)[::-1]):
    print("#",ind + 1, "Feature:", X.columns[item], ":", clf.feature_importances_[item])
# Out:
# # 1 Feature: Light : 0.3885138047352455
# # 2 Feature: CO2 : 0.2523149179163643
# # 3 Feature: Temperature : 0.10367590862936667
# # 4 Feature: hour : 0.09170277606744673
# # 5 Feature: HumidityRatio : 0.056995470842570055
# # 6 Feature: Humidity : 0.03490271950264244
# # 7 Feature: day_of_week : 0.03104484108560288
# # 8 Feature: month : 0.028661572947871795
# # 9 Feature: minute : 0.012187988272889827
# # 10 Feature: day : 0.0
# # 11 Feature: year : 0.0

# %%
# We see that our top 5 features are Light, CO2, Temperature, Hour, and Humidity ratio, let us use these features to train

# %%
X = X[["Light", "CO2", "Temperature", "hour", "HumidityRatio"]]
y = y

# %%
X
# Out:
#             Light         CO2  Temperature  hour  HumidityRatio
# 0      585.200000  749.200000      23.7000    14       0.004764
# 1      578.400000  760.400000      23.7180    14       0.004773
# 2      572.666667  769.666667      23.7300    14       0.004765
# 3      493.750000  774.750000      23.7225    14       0.004744
# 4      488.600000  779.000000      23.7540    14       0.004767
# ...           ...         ...          ...   ...            ...
# 10803  433.000000  787.250000      21.0500     9       0.005579
# 10804  433.000000  789.500000      21.0500     9       0.005563
# 10805  433.000000  798.500000      21.1000     9       0.005596
# 10806  433.000000  820.333333      21.1000     9       0.005621
# 10807  447.000000  821.000000      21.1000     9       0.005612
#
# [10808 rows x 5 columns]

# %%
# Scale features to normal
X = preprocessing.StandardScaler().fit_transform(X)
y = y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# We see that our data is not balanced, so we must train on balanced accuracy
y.describe()
# Out:
# count    10808.000000
# mean         0.249907
# std          0.432979
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: Occupancy, dtype: float64

# %% [markdown]
# ## SVM

# %%
estimator = SVC()
param_grid = {'C': [1, 10, 100, 1000], 'kernel': ["linear", "poly", "rbf"]} 
 
search = GridSearchCV(estimator, param_grid=param_grid, scoring = 'balanced_accuracy', verbose = 3)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.988, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.989, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] .................. C=1, kernel=linear, score=0.990, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.986, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.988, total=   0.1s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.987, total=   0.1s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.990, total=   0.1s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.991, total=   0.1s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.988, total=   0.1s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.986, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.988, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.992, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.990, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.991, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.989, total=   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.987, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.989, total=   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.990, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.986, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.988, total=   0.2s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.988, total=   0.1s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.991, total=   0.1s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.993, total=   0.1s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.990, total=   0.1s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.989, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.989, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.992, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.992, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.992, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.989, total=   0.1s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.987, total=   0.6s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.989, total=   0.5s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.990, total=   0.5s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.986, total=   0.5s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.988, total=   0.5s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.990, total=   0.3s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.992, total=   0.2s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.993, total=   0.2s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.992, total=   0.3s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.990, total=   0.3s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.989, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.984, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.992, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.988, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.989, total=   0.1s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.987, total=   3.6s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.989, total=   3.1s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.990, total=   3.7s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.986, total=   4.9s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.988, total=   4.1s
# [CV] C=1000, kernel=poly .............................................
# [CV] ................. C=1000, kernel=poly, score=0.990, total=   1.1s
# [CV] C=1000, kernel=poly .............................................
# [CV] ................. C=1000, kernel=poly, score=0.990, total=   1.3s
# [CV] C=1000, kernel=poly .............................................
# [CV] ................. C=1000, kernel=poly, score=0.993, total=   1.6s
# [CV] C=1000, kernel=poly .............................................
# [CV] ................. C=1000, kernel=poly, score=0.992, total=   1.2s
# [CV] C=1000, kernel=poly .............................................
# [CV] ................. C=1000, kernel=poly, score=0.990, total=   1.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] .................. C=1000, kernel=rbf, score=0.988, total=   0.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] .................. C=1000, kernel=rbf, score=0.982, total=   0.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] .................. C=1000, kernel=rbf, score=0.990, total=   0.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] .................. C=1000, kernel=rbf, score=0.987, total=   0.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] .................. C=1000, kernel=rbf, score=0.992, total=   0.2s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   34.0s finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100, 1000],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='balanced_accuracy', verbose=3)

# %%
pd.DataFrame(search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 7        0.261700      0.052406         0.005984        0.000892     100
# 10       1.241477      0.162537         0.008378        0.001954    1000
# 5        0.067420      0.004068         0.007181        0.000399      10
# 4        0.084973      0.008727         0.005785        0.000746      10
# 2        0.066422      0.002720         0.008776        0.001163       1
# 1        0.078989      0.003241         0.009175        0.001163       1
# 8        0.093350      0.006200         0.006981        0.001093     100
# 0        0.069614      0.011308         0.006582        0.001621       1
# 3        0.161767      0.018652         0.006383        0.001197      10
# 6        0.522004      0.025433         0.004986        0.000630     100
# 9        3.886400      0.602252         0.006184        0.001163    1000
# 11       0.180118      0.015483         0.008577        0.001850    1000
#
#    param_kernel                           params  split0_test_score  \
# 7          poly     {'C': 100, 'kernel': 'poly'}           0.989580
# 10         poly    {'C': 1000, 'kernel': 'poly'}           0.989580
# 5           rbf       {'C': 10, 'kernel': 'rbf'}           0.989236
# 4          poly      {'C': 10, 'kernel': 'poly'}           0.988409
# 2           rbf        {'C': 1, 'kernel': 'rbf'}           0.988065
# 1          poly       {'C': 1, 'kernel': 'poly'}           0.986874
# 8           rbf      {'C': 100, 'kernel': 'rbf'}           0.989196
# 0        linear     {'C': 1, 'kernel': 'linear'}           0.988449
# 3        linear    {'C': 10, 'kernel': 'linear'}           0.987278
# 6        linear   {'C': 100, 'kernel': 'linear'}           0.987278
# 9        linear  {'C': 1000, 'kernel': 'linear'}           0.987278
# 11          rbf     {'C': 1000, 'kernel': 'rbf'}           0.987622
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 7            0.991513           0.992685           0.991514
# 10           0.990339           0.992685           0.991514
# 5            0.991558           0.991551           0.991917
# 4            0.991129           0.992685           0.990343
# 2            0.991558           0.990380           0.991149
# 1            0.990362           0.991130           0.988001
# 8            0.984087           0.991898           0.987598
# 0            0.989211           0.989996           0.986081
# 3            0.989211           0.989996           0.986081
# 6            0.989211           0.989996           0.986081
# 9            0.989211           0.989996           0.986081
# 11           0.982123           0.990324           0.986811
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 7            0.989978         0.991054        0.001132                1
# 10           0.989978         0.990819        0.001135                2
# 5            0.989247         0.990702        0.001200                3
# 4            0.988807         0.990274        0.001561                4
# 2            0.988863         0.990003        0.001336                5
# 1            0.985697         0.988413        0.002054                6
# 8            0.989191         0.988394        0.002559                7
# 0            0.987692         0.988286        0.001343                8
# 3            0.987692         0.988052        0.001396                9
# 6            0.987692         0.988052        0.001396                9
# 9            0.987692         0.988052        0.001396                9
# 11           0.991917         0.987759        0.003363               12

# %% [markdown]
# SVC Best Estimator: {'C': 100, 'kernel': 'poly'}
#
# Training Accuracy (mean over 5-folds): 0.991054

# %%
svc_clf = search

# %%
svc_clf.best_estimator_.score(X_test, y_test)
# Out:
# 0.9884366327474561

# %% [markdown]
# ## Random Forests

# %%
estimator = RandomForestClassifier()
param_grid = {"criterion": ["gini", "entropy"], "n_estimators": [10, 100, 1000]} 
 
search = GridSearchCV(estimator, param_grid=param_grid, scoring = 'balanced_accuracy', verbose = 3)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.990, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.985, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.988, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.988, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.991, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.992, total=   0.3s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.986, total=   0.5s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.988, total=   0.4s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.990, total=   0.4s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.992, total=   0.4s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.991, total=   5.1s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.986, total=   3.9s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.991, total=   3.9s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.991, total=   4.2s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.992, total=   3.6s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.988, total=   0.0s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.984, total=   0.0s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.991, total=   0.0s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.991, total=   0.0s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.991, total=   0.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.991, total=   0.4s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.985, total=   0.4s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.991, total=   0.4s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.992, total=   0.5s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.992, total=   0.4s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.991, total=   4.1s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.985, total=   4.0s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.991, total=   4.2s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.992, total=   3.9s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.992, total=   3.9s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   45.2s finished
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [10, 100, 1000]},
#              scoring='balanced_accuracy', verbose=3)

# %%
pd.DataFrame(search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5       3.857876      0.118093         0.159972        0.017702
# 4       0.416485      0.024467         0.018750        0.002130
# 2       3.934870      0.523718         0.191687        0.027374
# 1       0.376792      0.034198         0.019747        0.002706
# 3       0.040891      0.010073         0.003989        0.001262
# 0       0.033111      0.001323         0.003191        0.000398
#
#   param_criterion param_n_estimators  \
# 5         entropy               1000
# 4         entropy                100
# 2            gini               1000
# 1            gini                100
# 3         entropy                 10
# 0            gini                 10
#
#                                            params  split0_test_score  \
# 5  {'criterion': 'entropy', 'n_estimators': 1000}           0.991459
# 4   {'criterion': 'entropy', 'n_estimators': 100}           0.991459
# 2     {'criterion': 'gini', 'n_estimators': 1000}           0.990692
# 1      {'criterion': 'gini', 'n_estimators': 100}           0.992246
# 3    {'criterion': 'entropy', 'n_estimators': 10}           0.987946
# 0       {'criterion': 'gini', 'n_estimators': 10}           0.989904
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 5           0.984832           0.991457           0.992263           0.991860
# 4           0.984832           0.990670           0.991879           0.992244
# 2           0.986006           0.990670           0.990708           0.991860
# 1           0.986389           0.988328           0.989537           0.991860
# 3           0.984019           0.990670           0.991092           0.990689
# 0           0.985216           0.988328           0.987963           0.991073
#
#    mean_test_score  std_test_score  rank_test_score
# 5         0.990374        0.002787                1
# 4         0.990217        0.002743                2
# 2         0.989987        0.002042                3
# 1         0.989672        0.002192                4
# 3         0.988883        0.002678                5
# 0         0.988497        0.001985                6

# %% [markdown]
# RF Best Estimator: {'criterion': 'entropy', 'n_estimators': 1000}
#
# Training Score (mean over 5-folds): 0.990605

# %%
rf_clf = search

# %%
rf_clf.best_estimator_.score(X_test, y_test)
# Out:
# 0.9916743755781684

# %% [markdown]
# ## Removing Light

# %%
X = X[:, 1:]
y = y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## SVM (again)

# %%
estimator = SVC()
param_grid = {'C': [1, 10, 100], 'kernel': ["linear", "poly", "rbf"]} 
 
search = GridSearchCV(estimator, param_grid=param_grid, scoring = 'balanced_accuracy', verbose = 3)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, kernel=linear ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................. C=1, kernel=linear, score=0.898, total=   0.2s
# [CV] C=1, kernel=linear ..............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] .................. C=1, kernel=linear, score=0.890, total=   0.2s
# [CV] C=1, kernel=linear ..............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] .................. C=1, kernel=linear, score=0.892, total=   0.3s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.876, total=   0.2s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.886, total=   0.2s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.898, total=   0.2s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.884, total=   0.3s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.896, total=   0.2s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.876, total=   0.2s
# [CV] C=1, kernel=poly ................................................
# [CV] .................... C=1, kernel=poly, score=0.880, total=   0.2s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.966, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.966, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.968, total=   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.958, total=   0.2s
# [CV] C=1, kernel=rbf .................................................
# [CV] ..................... C=1, kernel=rbf, score=0.968, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.898, total=   0.7s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.890, total=   0.5s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.892, total=   0.7s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.879, total=   0.6s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.885, total=   0.6s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.910, total=   0.4s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.899, total=   0.3s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.908, total=   0.3s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.887, total=   0.3s
# [CV] C=10, kernel=poly ...............................................
# [CV] ................... C=10, kernel=poly, score=0.898, total=   0.3s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.971, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.973, total=   0.2s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.974, total=   0.2s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.974, total=   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] .................... C=10, kernel=rbf, score=0.973, total=   0.1s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.898, total=   2.7s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.889, total=   2.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.892, total=   2.5s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.879, total=   2.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.885, total=   2.6s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.936, total=   0.7s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.926, total=   0.9s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.933, total=   0.8s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.917, total=   0.7s
# [CV] C=100, kernel=poly ..............................................
# [CV] .................. C=100, kernel=poly, score=0.933, total=   0.9s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.976, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.977, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.975, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.981, total=   0.1s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................... C=100, kernel=rbf, score=0.976, total=   0.2s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   25.8s finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='balanced_accuracy', verbose=3)

# %%
pd.DataFrame(search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 8       0.134241      0.016909         0.012566        0.001849     100
# 5       0.128656      0.014779         0.017753        0.002849      10
# 2       0.139626      0.021987         0.020146        0.002130       1
# 7       0.800857      0.073240         0.014960        0.002274     100
# 4       0.301194      0.017560         0.016356        0.003373      10
# 3       0.596403      0.078034         0.015160        0.001466      10
# 6       2.495521      0.103049         0.017753        0.003420     100
# 0       0.217817      0.023916         0.015558        0.001017       1
# 1       0.202857      0.031264         0.017154        0.000399       1
#
#   param_kernel                          params  split0_test_score  \
# 8          rbf     {'C': 100, 'kernel': 'rbf'}           0.975991
# 5          rbf      {'C': 10, 'kernel': 'rbf'}           0.971347
# 2          rbf       {'C': 1, 'kernel': 'rbf'}           0.966299
# 7         poly    {'C': 100, 'kernel': 'poly'}           0.935894
# 4         poly     {'C': 10, 'kernel': 'poly'}           0.910437
# 3       linear   {'C': 10, 'kernel': 'linear'}           0.898118
# 6       linear  {'C': 100, 'kernel': 'linear'}           0.898118
# 0       linear    {'C': 1, 'kernel': 'linear'}           0.898118
# 1         poly      {'C': 1, 'kernel': 'poly'}           0.897901
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8           0.977157           0.975215           0.980648           0.976405
# 5           0.972869           0.973660           0.973641           0.973313
# 2           0.965871           0.968227           0.958072           0.968283
# 7           0.926033           0.933173           0.917070           0.932771
# 4           0.898564           0.908124           0.886587           0.897988
# 3           0.890122           0.891825           0.878560           0.885164
# 6           0.888948           0.891825           0.878560           0.885164
# 0           0.890122           0.891825           0.876218           0.885951
# 1           0.884412           0.895570           0.876029           0.879599
#
#    mean_test_score  std_test_score  rank_test_score
# 8         0.977083        0.001890                1
# 5         0.972966        0.000859                2
# 2         0.965351        0.003769                3
# 7         0.928988        0.006787                4
# 4         0.900340        0.008490                5
# 3         0.888758        0.006570                6
# 6         0.888523        0.006538                7
# 0         0.888447        0.007260                8
# 1         0.886702        0.008645                9

# %% [markdown]
# SVC Best Estimator: {'C': 100, 'kernel': 'rbf'}
#
# Training Accuracy (mean over 5-folds): 0.977083

# %%
svc_clf_no_light = search

# %%
svc_clf_no_light.best_estimator_.score(X_test, y_test)
# Out:
# 0.9750231267345051

# %% [markdown]
# ## Random Forests

# %%
estimator = RandomForestClassifier()
param_grid = {"criterion": ["gini", "entropy"], "n_estimators": [10, 100, 1000]} 
 
search = GridSearchCV(estimator, param_grid=param_grid, scoring = 'balanced_accuracy', verbose = 3)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.980, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.977, total=   0.1s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.984, total=   0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.980, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] criterion=gini, n_estimators=10 .................................
# [CV] ..... criterion=gini, n_estimators=10, score=0.986, total=   0.0s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.986, total=   0.4s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.979, total=   0.4s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.982, total=   0.5s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.986, total=   0.4s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.988, total=   0.4s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.985, total=   4.4s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.977, total=   4.1s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.981, total=   4.5s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.983, total=   4.2s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.987, total=   4.3s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.978, total=   0.1s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.975, total=   0.1s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.979, total=   0.1s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.985, total=   0.1s
# [CV] criterion=entropy, n_estimators=10 ..............................
# [CV] .. criterion=entropy, n_estimators=10, score=0.988, total=   0.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.985, total=   0.5s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.977, total=   0.5s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.983, total=   0.5s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.985, total=   0.5s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.986, total=   0.5s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.985, total=   4.8s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.978, total=   4.8s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.983, total=   4.8s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.983, total=   4.8s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.988, total=   4.9s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   50.7s finished
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [10, 100, 1000]},
#              scoring='balanced_accuracy', verbose=3)

# %%
pd.DataFrame(search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       0.413493      0.034575         0.020745        0.002779
# 4       0.464556      0.023188         0.019349        0.001955
# 5       4.650156      0.036183         0.183908        0.020259
# 2       4.095440      0.099764         0.189692        0.022116
# 0       0.041488      0.002932         0.003590        0.000489
# 3       0.057247      0.005937         0.004388        0.000798
#
#   param_criterion param_n_estimators  \
# 1            gini                100
# 4         entropy                100
# 5         entropy               1000
# 2            gini               1000
# 0            gini                 10
# 3         entropy                 10
#
#                                            params  split0_test_score  \
# 1      {'criterion': 'gini', 'n_estimators': 100}           0.985624
# 4   {'criterion': 'entropy', 'n_estimators': 100}           0.985240
# 5  {'criterion': 'entropy', 'n_estimators': 1000}           0.985240
# 2     {'criterion': 'gini', 'n_estimators': 1000}           0.985240
# 0       {'criterion': 'gini', 'n_estimators': 10}           0.980173
# 3    {'criterion': 'entropy', 'n_estimators': 10}           0.978215
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           0.978986           0.981743           0.986408           0.987963
# 4           0.977428           0.983298           0.985237           0.986408
# 5           0.977812           0.982914           0.982895           0.987963
# 2           0.977428           0.980591           0.982511           0.986792
# 0           0.977406           0.983663           0.980169           0.985621
# 3           0.974675           0.979036           0.985237           0.987579
#
#    mean_test_score  std_test_score  rank_test_score
# 1         0.984145        0.003295                1
# 4         0.983522        0.003206                2
# 5         0.983365        0.003344                3
# 2         0.982513        0.003326                4
# 0         0.981406        0.002895                5
# 3         0.980948        0.004751                6

# %% [markdown]
# RF Best Estimator: {'criterion': 'entropy', 'n_estimators': 1000}
#
# Training Score (mean over 5-folds): 0.983292

# %%
rf_clf_no_light = search

# %%
rf_clf_no_light.best_estimator_.score(X_test, y_test)
# Out:
# 0.9888991674375578
