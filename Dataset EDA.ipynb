# %% [markdown]
#  # Importing Significant Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels
import numpy as np
import seaborn as sns
from numpy import array
from scipy.stats import norm
from statsmodels.formula.api import logit
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Data Exploration

# %%
# Reading in Data
data = pd.read_csv("occupancy.csv")

# %%
# Visualizing Structure
data.head()
# Out:
#                date  Temperature  Humidity       Light         CO2  \
# 0  02/02/2015 14:19      23.7000    26.272  585.200000  749.200000
# 1  02/02/2015 14:19      23.7180    26.290  578.400000  760.400000
# 2  02/02/2015 14:21      23.7300    26.230  572.666667  769.666667
# 3  02/02/2015 14:22      23.7225    26.125  493.750000  774.750000
# 4  02/02/2015 14:23      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy
# 0       0.004764          1
# 1       0.004773          1
# 2       0.004765          1
# 3       0.004744          1
# 4       0.004767          1

# %%
# Splitting the date column into date and time

data[["Date", "Time"]] = data.date.str.split(expand=True)
data.head()
# Out:
#                date  Temperature  Humidity       Light         CO2  \
# 0  02/02/2015 14:19      23.7000    26.272  585.200000  749.200000
# 1  02/02/2015 14:19      23.7180    26.290  578.400000  760.400000
# 2  02/02/2015 14:21      23.7300    26.230  572.666667  769.666667
# 3  02/02/2015 14:22      23.7225    26.125  493.750000  774.750000
# 4  02/02/2015 14:23      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy        Date   Time
# 0       0.004764          1  02/02/2015  14:19
# 1       0.004773          1  02/02/2015  14:19
# 2       0.004765          1  02/02/2015  14:21
# 3       0.004744          1  02/02/2015  14:22
# 4       0.004767          1  02/02/2015  14:23

# %%
# Drop the initial date column
data = data.drop(["date"], axis=1)
data.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy  \
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1
#
#          Date   Time
# 0  02/02/2015  14:19
# 1  02/02/2015  14:19
# 2  02/02/2015  14:21
# 3  02/02/2015  14:22
# 4  02/02/2015  14:23

# %%
# Looking for the first occurence of a weekend begins on the 5914ith observation
data.iloc[5913:]
# Out:
#        Temperature  Humidity  Light         CO2  HumidityRatio  Occupancy  \
# 5913       20.0000   18.7000    0.0  440.000000       0.002696          0
# 5914       20.0000   18.7000    0.0  438.000000       0.002696          0
# 5915       19.9725   18.7450    0.0  433.666667       0.002698          0
# 5916       20.0000   18.7900    0.0  434.500000       0.002709          0
# 5917       20.0000   18.7000    0.0  434.000000       0.002696          0
# ...            ...       ...    ...         ...            ...        ...
# 10803      21.0500   36.0975  433.0  787.250000       0.005579          1
# 10804      21.0500   35.9950  433.0  789.500000       0.005563          1
# 10805      21.1000   36.0950  433.0  798.500000       0.005596          1
# 10806      21.1000   36.2600  433.0  820.333333       0.005621          1
# 10807      21.1000   36.2000  447.0  821.000000       0.005612          1
#
#              Date   Time
# 5913   06/02/2015  23:58
# 5914   07/02/2015  00:00
# 5915   07/02/2015  00:01
# 5916   07/02/2015  00:02
# 5917   07/02/2015  00:03
# ...           ...    ...
# 10803  10/02/2015  09:29
# 10804  10/02/2015  09:29
# 10805  10/02/2015  09:30
# 10806  10/02/2015  09:32
# 10807  10/02/2015  09:33
#
# [4895 rows x 8 columns]

# %%
# The weekend ends on the 8794th observation with the rest being weekdays
data.iloc[8792:]
# Out:
#        Temperature  Humidity  Light         CO2  HumidityRatio  Occupancy  \
# 8792         19.50   27.1000    0.0  459.000000       0.003795          0
# 8793         19.50   27.1000    0.0  458.000000       0.003795          0
# 8794         19.50   27.1000    0.0  459.000000       0.003795          0
# 8795         19.50   27.1000    0.0  459.000000       0.003795          0
# 8796         19.50   27.1000    0.0  458.000000       0.003795          0
# ...            ...       ...    ...         ...            ...        ...
# 10803        21.05   36.0975  433.0  787.250000       0.005579          1
# 10804        21.05   35.9950  433.0  789.500000       0.005563          1
# 10805        21.10   36.0950  433.0  798.500000       0.005596          1
# 10806        21.10   36.2600  433.0  820.333333       0.005621          1
# 10807        21.10   36.2000  447.0  821.000000       0.005612          1
#
#              Date   Time
# 8792   08/02/2015  23:57
# 8793   08/02/2015  23:58
# 8794   09/02/2015  00:00
# 8795   09/02/2015  00:01
# 8796   09/02/2015  00:02
# ...           ...    ...
# 10803  10/02/2015  09:29
# 10804  10/02/2015  09:29
# 10805  10/02/2015  09:30
# 10806  10/02/2015  09:32
# 10807  10/02/2015  09:33
#
# [2016 rows x 8 columns]

# %%
# Setting a new binary column parameter known as day
data[["Day"]] = "weekday"
data.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy  \
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1
#
#          Date   Time      Day
# 0  02/02/2015  14:19  weekday
# 1  02/02/2015  14:19  weekday
# 2  02/02/2015  14:21  weekday
# 3  02/02/2015  14:22  weekday
# 4  02/02/2015  14:23  weekday

# %%
# Setting the days that are weekends manually
data.loc[5914:8793, "Day"] = "weekend"
data.iloc[5913:8795]
# Out:
#       Temperature  Humidity  Light         CO2  HumidityRatio  Occupancy  \
# 5913      20.0000    18.700    0.0  440.000000       0.002696          0
# 5914      20.0000    18.700    0.0  438.000000       0.002696          0
# 5915      19.9725    18.745    0.0  433.666667       0.002698          0
# 5916      20.0000    18.790    0.0  434.500000       0.002709          0
# 5917      20.0000    18.700    0.0  434.000000       0.002696          0
# ...           ...       ...    ...         ...            ...        ...
# 8790      19.5000    27.000    0.0  456.000000       0.003781          0
# 8791      19.5000    27.100    0.0  456.000000       0.003795          0
# 8792      19.5000    27.100    0.0  459.000000       0.003795          0
# 8793      19.5000    27.100    0.0  458.000000       0.003795          0
# 8794      19.5000    27.100    0.0  459.000000       0.003795          0
#
#             Date   Time      Day
# 5913  06/02/2015  23:58  weekday
# 5914  07/02/2015  00:00  weekend
# 5915  07/02/2015  00:01  weekend
# 5916  07/02/2015  00:02  weekend
# 5917  07/02/2015  00:03  weekend
# ...          ...    ...      ...
# 8790  08/02/2015  23:55  weekend
# 8791  08/02/2015  23:57  weekend
# 8792  08/02/2015  23:57  weekend
# 8793  08/02/2015  23:58  weekend
# 8794  09/02/2015  00:00  weekday
#
# [2882 rows x 9 columns]

# %%
# Changing the time to have a seconds for the timetodelta method
data["Time"] = data["Time"] + ":00"
data.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy  \
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1
#
#          Date      Time      Day
# 0  02/02/2015  14:19:00  weekday
# 1  02/02/2015  14:19:00  weekday
# 2  02/02/2015  14:21:00  weekday
# 3  02/02/2015  14:22:00  weekday
# 4  02/02/2015  14:23:00  weekday

# %%
data["Time"] = pd.to_timedelta(data["Time"])
data.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy  \
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1
#
#          Date            Time      Day
# 0  02/02/2015 0 days 14:19:00  weekday
# 1  02/02/2015 0 days 14:19:00  weekday
# 2  02/02/2015 0 days 14:21:00  weekday
# 3  02/02/2015 0 days 14:22:00  weekday
# 4  02/02/2015 0 days 14:23:00  weekday

# %%
# Setting a new categorical variable to specify the day of time
b = pd.to_timedelta(['00:00:00','07:00:00','19:00:00','24:00:00'])
l = ['Night','Day','Night']
data["dayoftime"] = pd.cut(data["Time"], bins=b, labels=l,ordered=False)
data.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy  \
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1
#
#          Date            Time      Day dayoftime
# 0  02/02/2015 0 days 14:19:00  weekday       Day
# 1  02/02/2015 0 days 14:19:00  weekday       Day
# 2  02/02/2015 0 days 14:21:00  weekday       Day
# 3  02/02/2015 0 days 14:22:00  weekday       Day
# 4  02/02/2015 0 days 14:23:00  weekday       Day

# %% [markdown]
# Here we are now left with a relatively cleaner dataframe in terms of date along with an added Day parameter from EDA.

# %%
data.to_csv("cleaned_occupancy.csv", index=False)

# %% [markdown]
# ##

# %% [markdown]
# #

# %% [markdown]
# # Checking for Disruptive Noise/Bias

# %%
print(data.any())
# Out:
# Temperature      True
# Humidity         True
# Light            True
# CO2              True
# HumidityRatio    True
# Occupancy        True
# Date             True
# Time             True
# Day              True
# dayoftime        True
# dtype: bool

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10808 entries, 0 to 10807
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    10808 non-null  float64
#  1   Humidity       10808 non-null  float64
#  2   Light          10808 non-null  float64
#  3   CO2            10808 non-null  float64
#  4   HumidityRatio  10808 non-null  float64
#  5   Occupancy      10808 non-null  int64
#  6   Date           10808 non-null  object
#  7   Time           10808 non-null  timedelta64[ns]
#  8   Day            10808 non-null  object
#  9   dayoftime      10800 non-null  category
# dtypes: category(1), float64(5), int64(1), object(2), timedelta64[ns](1)
# memory usage: 770.7+ KB
# None

# %%
#print(data['Temperature'].unique())

# %%
#print(data['Humidity'].unique())

# %%
#print( data['Light'].unique())

# %% [markdown]
# # Removing any rows with NaN values
# ## Ensures a better estimation by eliminating nonexistent values

# %%
data.shape
# Out:
# (10808, 10)

# %%
data.dropna(subset=['Temperature', 'Humidity','Light','CO2','HumidityRatio','Occupancy','Date','Time','Day','dayoftime'],inplace=True)

# %%
data.shape
# Out:
# (10800, 10)

# %% [markdown]
# ## As noticed, 8 rows were removed due to any missing value in any column
# ### running print(data.info()), we can notice that the column day of time had 10800 non-null values, hence being the remmoved NaN values
# ### look at rows

# %% [markdown]
# # One-Hot Encode Nominal Feature Vectors

# %%
columns= ['Day','dayoftime']

columns_encoding = pd.DataFrame(data,columns=columns)
print(columns_encoding.shape)
print( columns_encoding)
# Out:
# (10800, 2)
#            Day dayoftime
# 0      weekday       Day
# 1      weekday       Day
# 2      weekday       Day
# 3      weekday       Day
# 4      weekday       Day
# ...        ...       ...
# 10803  weekday       Day
# 10804  weekday       Day
# 10805  weekday       Day
# 10806  weekday       Day
# 10807  weekday       Day
#
# [10800 rows x 2 columns]

# %%
value_encoder = ['weekday','weekend','Day','Night']
values = array(data)
onehot_encoder = OneHotEncoder(sparse=False)
#integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
print(onehot_encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-ffc98d64cd85> in <module>
#       3 onehot_encoder = OneHotEncoder(sparse=False)
#       4 #integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
# ----> 5 onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
#       6 print(onehot_encoded)
#
# NameError: name 'integer_encoded' is not defined

# %%
sk.preprocessing.OneHotEncoder()
